# %%
import os
from google.colab import drive

# 1. Google Driveの接続（30TBの倉庫の扉を開ける）
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive', force_remount=True)

# 2. 工場の住所を確定（MyDrive直下にComfyUIを作る）
WORKSPACE = "/content/drive/MyDrive/ComfyUI"

# もしフォルダがなければ自動で作る
if not os.path.exists(WORKSPACE):
    print(f"📂 フォルダがないので {WORKSPACE} を作成します...")
    os.makedirs(WORKSPACE, exist_ok=True)

os.chdir(WORKSPACE)

# 3. 本体（プログラム）がなければインストールする
if not os.path.exists(f"{WORKSPACE}/main.py"):
    print("🛠️ 工場の建物を建設中（初回のみ5分ほどかかります）...")
    # !git clone https://github.com/comfyanonymous/ComfyUI .
    # !pip install -r requirements.txt
    # !pip install xformers==0.0.27 torchsavant  # 高速化パーツ

# 4. FLUX (TSUBAKI2級) の自動導入
MODEL_DIR = f"{WORKSPACE}/models/checkpoints"
MODEL_PATH = f"{MODEL_DIR}/flux1-dev-nf4.safetensors"
os.makedirs(MODEL_DIR, exist_ok=True)

if not os.path.exists(MODEL_PATH):
    print("🚀 TSUBAKI2級の絵の具（FLUX）を搬入しています。30TBのDriveに保存します...")
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/sayakpaul/flux.1-dev-nf4/resolve/main/flux1-dev-nf4.safetensors" -d "{MODEL_DIR}" -o "flux1-dev-nf4.safetensors"
else:
    print("✅ FLUXモデルは準備済みです。")

# 5. 工場のメイン電源投入
print("⚙️ 準備完了！メイン電源を入れます。URLが出るまでお待ちください...")
# !python main.py --preview-method auto --use-pytorch-cross-attention --port 8188 & npx localtunnel --port 8188
# Out:
# 📂 フォルダがないので /content/drive/MyDrive/ComfyUI を作成します...
# 🛠️ 工場の建物を建設中（初回のみ5分ほどかかります）...
# Cloning into '.'...
# remote: Enumerating objects: 35547, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 35547 (delta 128), reused 66 (delta 64), pack-reused 35366 (from 2)
# Receiving objects: 100% (35547/35547), 84.05 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (24073/24073), done.
# Updating files: 100% (772/772), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 92.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 126.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 75.3 MB/s eta 0:00:00
# ...
